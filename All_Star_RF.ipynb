# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix as cm
from sklearn.ensemble import RandomForestClassifier

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Notebook Overview

# %% [markdown]
# For this project, I applied data mining techniques to a dataset consisting of pre-draft metrics and statistics for NBA players to determine whether or not it was possible to create accurate models that could predict whether or not an NBA prospect would develop into a future All-Star.
#
# This notebook contains the analysis performed to develop Random Forest models with this goal in mind.
#
# For each model, hypothetical players numbered from 1-4 are supplied to test predictions into whether or not the model believes that they could develop into All-Stars or not. Players 1 and 2 represent Backcourt players (Point Guards and Shooting Guards), and Players 3 and 4 represent Frontcourt players (Small Forwards, Power Forwards, and Centers). These players are to be thought of as prospects that are up to be drafted into the NBA, and we as the user are to think of ourselves as GMs assessing them through our trained models.

# %% [markdown]
# ## Loading the Data

# %%
data = 'C://Users//micha//Documents//DMII_Final_Project//draft_dataset.csv'

# %%
df_nba=pd.read_csv(data)

# %%
df_nba.head()
# Out:
#              Player  All_Star Position BC/FC  Height_No_Shoes  Height_Shoes  \
# 0        Dante Exum         0       PG    BC               77            78
# 1      Marcus Moore         0       SG    BC               76            77
# 2   DeAndre Liggins         0       SG    BC               77            78
# 3      Monte Morris         0       PG    BC               73            75
# 4  Kendall Marshall         0       PG    BC               75            76
#
#    Wingspan  Standing_Reach  Vertical_Max  Vertical_Max_Reach  \
# 0        82             103            35                 138
# 1        81             102            30                 132
# 2        83             104            31                 135
# 3        76              97            34                 130
# 4        78              96            37                 133
#
#    Vertical_No_Step  Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 0                32                     135   196.0                1.32
# 1                25                     127   202.0                1.32
# 2                27                     131   202.0                1.33
# 3                28                     125   175.0                1.29
# 4                31                     127   198.0                1.26
#
#    Wingspan_Height_Ratio   BMI  PTS  REB  AST   TPV
# 0                   1.05  23.5  2.7  1.5  2.0   8.8
# 1                   1.05  24.6  3.3  2.5  0.3   6.4
# 2                   1.06  24.0  5.8  3.0  2.1  13.6
# 3                   1.01  22.9  6.8  2.6  3.7  17.9
# 4                   1.03  24.6  7.2  2.3  8.0  28.0

# %%
df_nba.tail()
# Out:
#               Player  All_Star Position BC/FC  Height_No_Shoes  Height_Shoes  \
# 599      Elvin Hayes         1       PF    FC               80            81
# 600     Elgin Baylor         1       SF    FC               76            77
# 601     LeBron James         1       SF    FC               79            81
# 602  Spencer Haywood         1       PF    FC               79            80
# 603     Moses Malone         1        C    FC               81            82
#
#      Wingspan  Standing_Reach  Vertical_Max  Vertical_Max_Reach  \
# 599        84             106            34                 140
# 600        80             101            38                 139
# 601        84             106            44                 150
# 602        85             106            36                 142
# 603        86             110            35                 145
#
#      Vertical_No_Step  Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 599                30                     136   235.0                1.31
# 600                34                     135   225.0                1.31
# 601                39                     145   245.0                1.31
# 602                32                     138   230.0                1.33
# 603                30                     140   215.0                1.34
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 599                   1.04  25.8  31.0  17.2  1.4  50.9
# 600                   1.04  27.4  31.2  19.8  3.8  59.2
# 601                   1.04  27.4  31.6   9.6  4.6  51.6
# 602                   1.06  25.9  32.2  22.1  3.4  61.5
# 603                   1.05  23.0  36.0  26.0  1.5  64.6

# %% [markdown]
# In the context of this dataset, a "0" indicates that a player has never been named an All-Star, while a "1" indicates that a player has been named an All-Star.

# %%
df_nba.shape
# Out:
# (604, 20)

# %% [markdown]
# ## Checking for nulls

# %%
df_nba.isnull().sum()
# Out:
# Player                    0
# All_Star                  0
# Position                  0
# BC/FC                     0
# Height_No_Shoes           0
# Height_Shoes              0
# Wingspan                  0
# Standing_Reach            0
# Vertical_Max              0
# Vertical_Max_Reach        0
# Vertical_No_Step          0
# Vertical_No_Step_Reach    0
# Weight                    0
# Reach_Height_Ratio        0
# Wingspan_Height_Ratio     0
# BMI                       0
# PTS                       0
# REB                       0
# AST                       0
# TPV                       0
# dtype: int64

# %% [markdown]
# As we can see, we have no nulls entries in any of our columns.

# %% [markdown]
# ## Next, let's take a look at our dataset's balance with respect to our target classes

# %%
all_star_counts = df_nba['All_Star'].value_counts()

print(all_star_counts)
# Out:
# 0    302
# 1    302
# Name: All_Star, dtype: int64

# %% [markdown]
# As we can see, distribution of All-Stars to Non-All-Stars is equal.

# %% [markdown]
# ## Now with respect to our target classes and position

# %%
positions = ['PG', 'SG', 'SF', 'PF', 'C']

for position in positions:
    players_by_position = df_nba[df_nba['Position'] == position]
    
    all_star_counts = players_by_position['All_Star'].value_counts()
    
    print(f"{position}s:")
    print("All Stars:", all_star_counts[1])
    print("Non-All Stars:", all_star_counts[0])
    print()
# Out:
# PGs:
# All Stars: 54
# Non-All Stars: 54
#
# SGs:
# All Stars: 65
# Non-All Stars: 65
#
# SFs:
# All Stars: 57
# Non-All Stars: 57
#
# PFs:
# All Stars: 74
# Non-All Stars: 74
#
# Cs:
# All Stars: 52
# Non-All Stars: 52

# %% [markdown]
# ## Lastly, with respect to our target classes and whether or not a player's position is considered part of the Backcourt or Frontcourt.

# %%
bc_fcs = ['BC', 'FC']

for bc_fc in bc_fcs:
    players_by_bc_fc = df_nba[df_nba['BC/FC'] == bc_fc]
    
    all_star_counts = players_by_bc_fc['All_Star'].value_counts()
    
    print(f"{bc_fc}s:")
    print("All Stars:", all_star_counts[1])
    print("Non-All Stars:", all_star_counts[0])
    print()
# Out:
# BCs:
# All Stars: 119
# Non-All Stars: 119
#
# FCs:
# All Stars: 183
# Non-All Stars: 183

# %% [markdown]
# ## - Balance Check Complete -

# %% [markdown]
# ## Separating Backcourt and Frontcourt into Two New Dataframes
#
# Next, in order for the dataset to be mined for proper insights, it is important to create two separate dataframes that reflect data for Backcourt and Frontcourt players. The reason for this is that qualities that make a great Backcourt player (Point Guard or Shooting Guard) tend not to be the qualities that makes a great Frontcourt player (Small Forward, Power Forward, and Center).
#
# Before doing that, however, we will first drop the player column from the existing dataframe as they are not features that are not needed for any subsequent analysis that occurs past this point.

# %%
df_nba.drop('Player', axis=1, inplace=True)
df_nba
# Out:
#      All_Star Position BC/FC  Height_No_Shoes  Height_Shoes  Wingspan  \
# 0           0       PG    BC               77            78        82
# 1           0       SG    BC               76            77        81
# 2           0       SG    BC               77            78        83
# 3           0       PG    BC               73            75        76
# 4           0       PG    BC               75            76        78
# ..        ...      ...   ...              ...           ...       ...
# 599         1       PF    FC               80            81        84
# 600         1       SF    FC               76            77        80
# 601         1       SF    FC               79            81        84
# 602         1       PF    FC               79            80        85
# 603         1        C    FC               81            82        86
#
#      Standing_Reach  Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 0               103            35                 138                32
# 1               102            30                 132                25
# 2               104            31                 135                27
# 3                97            34                 130                28
# 4                96            37                 133                31
# ..              ...           ...                 ...               ...
# 599             106            34                 140                30
# 600             101            38                 139                34
# 601             106            44                 150                39
# 602             106            36                 142                32
# 603             110            35                 145                30
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 0                       135   196.0                1.32
# 1                       127   202.0                1.32
# 2                       131   202.0                1.33
# 3                       125   175.0                1.29
# 4                       127   198.0                1.26
# ..                      ...     ...                 ...
# 599                     136   235.0                1.31
# 600                     135   225.0                1.31
# 601                     145   245.0                1.31
# 602                     138   230.0                1.33
# 603                     140   215.0                1.34
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 0                     1.05  23.5   2.7   1.5  2.0   8.8
# 1                     1.05  24.6   3.3   2.5  0.3   6.4
# 2                     1.06  24.0   5.8   3.0  2.1  13.6
# 3                     1.01  22.9   6.8   2.6  3.7  17.9
# 4                     1.03  24.6   7.2   2.3  8.0  28.0
# ..                     ...   ...   ...   ...  ...   ...
# 599                   1.04  25.8  31.0  17.2  1.4  50.9
# 600                   1.04  27.4  31.2  19.8  3.8  59.2
# 601                   1.04  27.4  31.6   9.6  4.6  51.6
# 602                   1.06  25.9  32.2  22.1  3.4  61.5
# 603                   1.05  23.0  36.0  26.0  1.5  64.6
#
# [604 rows x 19 columns]

# %%
df_bc = df_nba[df_nba['BC/FC'] == 'BC']
df_fc = df_nba[df_nba['BC/FC'] == 'FC']

# %%
df_bc
# Out:
#      All_Star Position BC/FC  Height_No_Shoes  Height_Shoes  Wingspan  \
# 0           0       PG    BC               77            78        82
# 1           0       SG    BC               76            77        81
# 2           0       SG    BC               77            78        83
# 3           0       PG    BC               73            75        76
# 4           0       PG    BC               75            76        78
# ..        ...      ...   ...              ...           ...       ...
# 233         1       SG    BC               77            78        81
# 234         1       SG    BC               77            78        83
# 235         1       PG    BC               76            77        80
# 236         1       SG    BC               75            76        79
# 237         1       SG    BC               76            77        80
#
#      Standing_Reach  Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 0               103            35                 138                32
# 1               102            30                 132                25
# 2               104            31                 135                27
# 3                97            34                 130                28
# 4                96            37                 133                31
# ..              ...           ...                 ...               ...
# 233             102            32                 134                26
# 234             107            38                 145                33
# 235             101            38                 139                32
# 236             100            34                 134                28
# 237             101            36                 137                32
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 0                       135   196.0                1.32
# 1                       127   202.0                1.32
# 2                       131   202.0                1.33
# 3                       125   175.0                1.29
# 4                       127   198.0                1.26
# ..                      ...     ...                 ...
# 233                     128   180.0                1.31
# 234                     140   200.0                1.37
# 235                     133   205.0                1.31
# 236                     128   190.0                1.32
# 237                     133   251.0                1.31
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 0                     1.05  23.5   2.7   1.5  2.0   8.8
# 1                     1.05  24.6   3.3   2.5  0.3   6.4
# 2                     1.06  24.0   5.8   3.0  2.1  13.6
# 3                     1.01  22.9   6.8   2.6  3.7  17.9
# 4                     1.03  24.6   7.2   2.3  8.0  28.0
# ..                     ...   ...   ...   ...  ...   ...
# 233                   1.04  21.3  29.1   5.5  2.9  41.1
# 234                   1.06  24.0  30.8  12.0  6.5  57.5
# 235                   1.04  25.0  33.8  15.2  7.1  65.0
# 236                   1.04  23.7  34.6   7.3  3.3  49.3
# 237                   1.04  30.5  44.2   6.4  5.1  62.2
#
# [238 rows x 19 columns]

# %%
df_bc = df_bc.drop(columns=['BC/FC'])
df_bc
# Out:
#      All_Star Position  Height_No_Shoes  Height_Shoes  Wingspan  \
# 0           0       PG               77            78        82
# 1           0       SG               76            77        81
# 2           0       SG               77            78        83
# 3           0       PG               73            75        76
# 4           0       PG               75            76        78
# ..        ...      ...              ...           ...       ...
# 233         1       SG               77            78        81
# 234         1       SG               77            78        83
# 235         1       PG               76            77        80
# 236         1       SG               75            76        79
# 237         1       SG               76            77        80
#
#      Standing_Reach  Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 0               103            35                 138                32
# 1               102            30                 132                25
# 2               104            31                 135                27
# 3                97            34                 130                28
# 4                96            37                 133                31
# ..              ...           ...                 ...               ...
# 233             102            32                 134                26
# 234             107            38                 145                33
# 235             101            38                 139                32
# 236             100            34                 134                28
# 237             101            36                 137                32
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 0                       135   196.0                1.32
# 1                       127   202.0                1.32
# 2                       131   202.0                1.33
# 3                       125   175.0                1.29
# 4                       127   198.0                1.26
# ..                      ...     ...                 ...
# 233                     128   180.0                1.31
# 234                     140   200.0                1.37
# 235                     133   205.0                1.31
# 236                     128   190.0                1.32
# 237                     133   251.0                1.31
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 0                     1.05  23.5   2.7   1.5  2.0   8.8
# 1                     1.05  24.6   3.3   2.5  0.3   6.4
# 2                     1.06  24.0   5.8   3.0  2.1  13.6
# 3                     1.01  22.9   6.8   2.6  3.7  17.9
# 4                     1.03  24.6   7.2   2.3  8.0  28.0
# ..                     ...   ...   ...   ...  ...   ...
# 233                   1.04  21.3  29.1   5.5  2.9  41.1
# 234                   1.06  24.0  30.8  12.0  6.5  57.5
# 235                   1.04  25.0  33.8  15.2  7.1  65.0
# 236                   1.04  23.7  34.6   7.3  3.3  49.3
# 237                   1.04  30.5  44.2   6.4  5.1  62.2
#
# [238 rows x 18 columns]

# %%
df_bc = df_bc.drop(columns=['Position'])
df_bc
# Out:
#      All_Star  Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  \
# 0           0               77            78        82             103
# 1           0               76            77        81             102
# 2           0               77            78        83             104
# 3           0               73            75        76              97
# 4           0               75            76        78              96
# ..        ...              ...           ...       ...             ...
# 233         1               77            78        81             102
# 234         1               77            78        83             107
# 235         1               76            77        80             101
# 236         1               75            76        79             100
# 237         1               76            77        80             101
#
#      Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 0              35                 138                32
# 1              30                 132                25
# 2              31                 135                27
# 3              34                 130                28
# 4              37                 133                31
# ..            ...                 ...               ...
# 233            32                 134                26
# 234            38                 145                33
# 235            38                 139                32
# 236            34                 134                28
# 237            36                 137                32
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 0                       135   196.0                1.32
# 1                       127   202.0                1.32
# 2                       131   202.0                1.33
# 3                       125   175.0                1.29
# 4                       127   198.0                1.26
# ..                      ...     ...                 ...
# 233                     128   180.0                1.31
# 234                     140   200.0                1.37
# 235                     133   205.0                1.31
# 236                     128   190.0                1.32
# 237                     133   251.0                1.31
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 0                     1.05  23.5   2.7   1.5  2.0   8.8
# 1                     1.05  24.6   3.3   2.5  0.3   6.4
# 2                     1.06  24.0   5.8   3.0  2.1  13.6
# 3                     1.01  22.9   6.8   2.6  3.7  17.9
# 4                     1.03  24.6   7.2   2.3  8.0  28.0
# ..                     ...   ...   ...   ...  ...   ...
# 233                   1.04  21.3  29.1   5.5  2.9  41.1
# 234                   1.06  24.0  30.8  12.0  6.5  57.5
# 235                   1.04  25.0  33.8  15.2  7.1  65.0
# 236                   1.04  23.7  34.6   7.3  3.3  49.3
# 237                   1.04  30.5  44.2   6.4  5.1  62.2
#
# [238 rows x 17 columns]

# %%
df_fc = df_fc.drop(columns=['BC/FC'])
df_fc
# Out:
#      All_Star Position  Height_No_Shoes  Height_Shoes  Wingspan  \
# 238         0        C               84            85        86
# 239         0        C               85            86        89
# 240         0        C               80            81        86
# 241         0       SF               77            78        81
# 242         0        C               86            87        90
# ..        ...      ...              ...           ...       ...
# 599         1       PF               80            81        84
# 600         1       SF               76            77        80
# 601         1       SF               79            81        84
# 602         1       PF               79            80        85
# 603         1        C               81            82        86
#
#      Standing_Reach  Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 238             113            29                 142                21
# 239             112            30                 142                29
# 240             109            25                 134                23
# 241             104            36                 140                30
# 242             112            27                 139                24
# ..              ...           ...                 ...               ...
# 599             106            34                 140                30
# 600             101            38                 139                34
# 601             106            44                 150                39
# 602             106            36                 142                32
# 603             110            35                 145                30
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 238                     134   255.0                1.33
# 239                     141   289.0                1.30
# 240                     132   263.0                1.35
# 241                     134   208.0                1.33
# 242                     136   266.0                1.29
# ..                      ...     ...                 ...
# 599                     136   235.0                1.31
# 600                     135   225.0                1.31
# 601                     145   245.0                1.31
# 602                     138   230.0                1.33
# 603                     140   215.0                1.34
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 238                   1.01  25.4   1.3   1.7  0.1   3.2
# 239                   1.03  28.1   1.5   1.4  0.1   3.1
# 240                   1.06  28.9   1.5   1.5  2.5   8.8
# 241                   1.04  24.8   1.6   1.3  0.2   3.3
# 242                   1.03  25.3   1.8   0.7  0.0   2.5
# ..                     ...   ...   ...   ...  ...   ...
# 599                   1.04  25.8  31.0  17.2  1.4  50.9
# 600                   1.04  27.4  31.2  19.8  3.8  59.2
# 601                   1.04  27.4  31.6   9.6  4.6  51.6
# 602                   1.06  25.9  32.2  22.1  3.4  61.5
# 603                   1.05  23.0  36.0  26.0  1.5  64.6
#
# [366 rows x 18 columns]

# %%
df_fc = df_fc.drop(columns=['Position'])
df_fc
# Out:
#      All_Star  Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  \
# 238         0               84            85        86             113
# 239         0               85            86        89             112
# 240         0               80            81        86             109
# 241         0               77            78        81             104
# 242         0               86            87        90             112
# ..        ...              ...           ...       ...             ...
# 599         1               80            81        84             106
# 600         1               76            77        80             101
# 601         1               79            81        84             106
# 602         1               79            80        85             106
# 603         1               81            82        86             110
#
#      Vertical_Max  Vertical_Max_Reach  Vertical_No_Step  \
# 238            29                 142                21
# 239            30                 142                29
# 240            25                 134                23
# 241            36                 140                30
# 242            27                 139                24
# ..            ...                 ...               ...
# 599            34                 140                30
# 600            38                 139                34
# 601            44                 150                39
# 602            36                 142                32
# 603            35                 145                30
#
#      Vertical_No_Step_Reach  Weight  Reach_Height_Ratio  \
# 238                     134   255.0                1.33
# 239                     141   289.0                1.30
# 240                     132   263.0                1.35
# 241                     134   208.0                1.33
# 242                     136   266.0                1.29
# ..                      ...     ...                 ...
# 599                     136   235.0                1.31
# 600                     135   225.0                1.31
# 601                     145   245.0                1.31
# 602                     138   230.0                1.33
# 603                     140   215.0                1.34
#
#      Wingspan_Height_Ratio   BMI   PTS   REB  AST   TPV
# 238                   1.01  25.4   1.3   1.7  0.1   3.2
# 239                   1.03  28.1   1.5   1.4  0.1   3.1
# 240                   1.06  28.9   1.5   1.5  2.5   8.8
# 241                   1.04  24.8   1.6   1.3  0.2   3.3
# 242                   1.03  25.3   1.8   0.7  0.0   2.5
# ..                     ...   ...   ...   ...  ...   ...
# 599                   1.04  25.8  31.0  17.2  1.4  50.9
# 600                   1.04  27.4  31.2  19.8  3.8  59.2
# 601                   1.04  27.4  31.6   9.6  4.6  51.6
# 602                   1.06  25.9  32.2  22.1  3.4  61.5
# 603                   1.05  23.0  36.0  26.0  1.5  64.6
#
# [366 rows x 17 columns]

# %% [markdown]
# ## - Dataframe Separation Complete -

# %% [markdown]
# ## Model for Backcourt Players

# %% [markdown]
# ## Random Forest (BC)

# %%
y_target = df_bc['All_Star']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_bc.drop(['All_Star'], axis = 'columns'), y_target, test_size = 0.2)

# %%
rf_model1 = RandomForestClassifier(n_estimators=200,
                                  max_depth = 10,
                                  criterion = 'gini',
                                  random_state = 42)
rf_model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %%
y_pred = rf_model1.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy Score for Random Forest (BC):", round(accuracy * 100, 2), "%")
print("Precision Score for Random Forest (BC):", round(precision * 100, 2), "%")
print("Recall Score for Random Forest (BC):", round(recall * 100, 2), "%")
print("F1-Score for Random Forest (BC):", round(f1 * 100, 2), "%")
# Out:
# Accuracy Score for Random Forest (BC): 89.58 %
# Precision Score for Random Forest (BC): 86.36 %
# Recall Score for Random Forest (BC): 90.48 %
# F1-Score for Random Forest (BC): 88.37 %

# %%
cmrf1 = cm(y_test, y_pred)
cmrf1
# Out:
# array([[24,  3],
#        [ 2, 19]], dtype=int64)

# %%
ax = plt.subplot()
sns.heatmap(cmrf1, annot=True, fmt = 'g', ax=ax)
ax.set_xlabel('Predicted Class')
ax.set_ylabel('True Class')
ax.set_title('Random Forest Confusion Matrix (BC)')
# Out:
# Text(0.5, 1.0, 'Random Forest Confusion Matrix (BC)')

# %%
print(24/(24+3),19/(19+2))
# Out:
# 0.8888888888888888 0.9047619047619048

# %% [markdown]
# Result: The Random Forest model gets 88.88% of the non-All-Stars correct and 90.48% of the All-Stars correct when predicting for Backcourt players.

# %% [markdown]
# ## Player Predictions (BC)

# %% [markdown]
# ### Player 1
# A 6'1, 189-pound player with a 33-inch max vertical jump who averaged 8 points, 2 rebounds, and 3 assists per game.

# %%
player1 = {
    'Height_No_Shoes': 72,
    'Height_Shoes': 73,
    'Wingspan': 75,  
    'Standing_Reach': 97,
    'Vertical_Max': 33,
    'Vertical_Max_Reach': 130,
    'Vertical_No_Step': 27,
    'Vertical_No_Step_Reach': 124,
    'Weight': 189,
    'Reach_Height_Ratio': 1.33,
    'Wingspan_Height_Ratio': 1.03,
    'BMI': 24.9,
    'PTS': 8,
    'REB': 2,
    'AST': 3,
    'TPV': 16.9
}

player1_df = pd.DataFrame([player1])
player1_df
# Out:
#    Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  Vertical_Max  \
# 0               72            73        75              97            33
#
#    Vertical_Max_Reach  Vertical_No_Step  Vertical_No_Step_Reach  Weight  \
# 0                 130                27                     124     189
#
#    Reach_Height_Ratio  Wingspan_Height_Ratio   BMI  PTS  REB  AST   TPV
# 0                1.33                   1.03  24.9    8    2    3  16.9

# %%
prediction_player1 = rf_model1.predict(player1_df)

print('1 = All-Star')
print('0 = Not an All-Star')
print(f'For this player, the model predicts: {prediction_player1[0]}')
# Out:
# 1 = All-Star
# 0 = Not an All-Star
# For this player, the model predicts: 0

# %% [markdown]
# ### Player 2
# A 6'5, 205-pound player with a 38-inch max vertical jump who averaged 22 points, 4 rebounds, and 8 assists per game.

# %%
player2 = {
    'Height_No_Shoes': 76,
    'Height_Shoes': 77,
    'Wingspan': 83,  
    'Standing_Reach': 102,
    'Vertical_Max': 38,
    'Vertical_Max_Reach': 140,
    'Vertical_No_Step': 32,
    'Vertical_No_Step_Reach': 134,
    'Weight': 205,
    'Reach_Height_Ratio': 1.4,
    'Wingspan_Height_Ratio': 1.08,
    'BMI': 24.3,
    'PTS': 22,
    'REB': 4,
    'AST': 8,
    'TPV': 44.4
}

player2_df = pd.DataFrame([player2])
player2_df
# Out:
#    Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  Vertical_Max  \
# 0               76            77        83             102            38
#
#    Vertical_Max_Reach  Vertical_No_Step  Vertical_No_Step_Reach  Weight  \
# 0                 140                32                     134     205
#
#    Reach_Height_Ratio  Wingspan_Height_Ratio   BMI  PTS  REB  AST   TPV
# 0                 1.4                   1.08  24.3   22    4    8  44.4

# %%
prediction_player2 = rf_model1.predict(player2_df)

print('1 = All-Star')
print('0 = Not an All-Star')
print(f'For this player, the model predicts: {prediction_player2[0]}')
# Out:
# 1 = All-Star
# 0 = Not an All-Star
# For this player, the model predicts: 1

# %% [markdown]
# ## Model for Frontcourt Players

# %% [markdown]
# ## Random Forest (FC)

# %%
y_target = df_fc['All_Star']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_fc.drop(['All_Star'], axis = 'columns'), y_target, test_size = 0.2)

# %%
rf_model2 = RandomForestClassifier(n_estimators=200,
                                  max_depth = 10,
                                  criterion = 'gini',
                                  random_state = 42)
rf_model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %%
y_pred = rf_model2.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy Score for Random Forest (FC):", round(accuracy * 100, 2), "%")
print("Precision Score for Random Forest (FC):", round(precision * 100, 2), "%")
print("Recall Score for Random Forest (FC):", round(recall * 100, 2), "%")
print("F1-Score for Random Forest (FC):", round(f1 * 100, 2), "%")
# Out:
# Accuracy Score for Random Forest (FC): 90.54 %
# Precision Score for Random Forest (FC): 94.44 %
# Recall Score for Random Forest (FC): 87.18 %
# F1-Score for Random Forest (FC): 90.67 %

# %%
cmrf2 = cm(y_test, y_pred)
cmrf2
# Out:
# array([[33,  2],
#        [ 5, 34]], dtype=int64)

# %%
ax = plt.subplot()
sns.heatmap(cmrf2, annot=True, fmt = 'g', ax=ax)
ax.set_xlabel('Predicted Class')
ax.set_ylabel('True Class')
ax.set_title('Random Forest Confusion Matrix (FC)')
# Out:
# Text(0.5, 1.0, 'Random Forest Confusion Matrix (FC)')

# %%
print(33/(33+2),34/(34+5))
# Out:
# 0.9428571428571428 0.8717948717948718

# %% [markdown]
# Result: The Random Forest model gets 94.29% of the non-All-Stars correct and 87.18% of the All-Stars correct when predicting for Frontcourt players.

# %% [markdown]
# ## Player Predictions (FC)

# %% [markdown]
# ### Player 3
# A 6'5, 220-pound player with a 33-inch max vertical jump who averaged 12 points, 8 rebounds, and 2 assists per game.

# %%
player3 = {
    'Height_No_Shoes': 76,
    'Height_Shoes': 77,
    'Wingspan': 80,  
    'Standing_Reach': 105,
    'Vertical_Max': 33,
    'Vertical_Max_Reach': 141,
    'Vertical_No_Step': 28,
    'Vertical_No_Step_Reach': 136,
    'Weight': 220,
    'Reach_Height_Ratio': 1.4,
    'Wingspan_Height_Ratio': 1.08,
    'BMI': 26.1,
    'PTS': 12,
    'REB': 8,
    'AST': 2,
    'TPV': 24.4
}

player3_df = pd.DataFrame([player3])
player3_df
# Out:
#    Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  Vertical_Max  \
# 0               76            77        80             105            33
#
#    Vertical_Max_Reach  Vertical_No_Step  Vertical_No_Step_Reach  Weight  \
# 0                 141                28                     136     220
#
#    Reach_Height_Ratio  Wingspan_Height_Ratio   BMI  PTS  REB  AST   TPV
# 0                 1.4                   1.08  26.1   12    8    2  24.4

# %%
prediction_player3 = rf_model2.predict(player3_df)

print('1 = All-Star')
print('0 = Not an All-Star')
print(f'For this player, the model predicts: {prediction_player3[0]}')
# Out:
# 1 = All-Star
# 0 = Not an All-Star
# For this player, the model predicts: 0

# %% [markdown]
# ### Player 4
# A 6'10, 210-pound player with a 37-inch max vertical jump who averaged 18 points, 7 rebounds, and 4 assists per game.

# %%
player4 = {
    'Height_No_Shoes': 81,
    'Height_Shoes': 82,
    'Wingspan': 86,  
    'Standing_Reach': 110,
    'Vertical_Max': 37,
    'Vertical_Max_Reach': 147,
    'Vertical_No_Step': 33,
    'Vertical_No_Step_Reach': 143,
    'Weight': 210,
    'Reach_Height_Ratio': 1.34,
    'Wingspan_Height_Ratio': 1.05,
    'BMI': 22,
    'PTS': 18,
    'REB': 7,
    'AST': 4,
    'TPV': 34
}

player4_df = pd.DataFrame([player4])
player4_df
# Out:
#    Height_No_Shoes  Height_Shoes  Wingspan  Standing_Reach  Vertical_Max  \
# 0               81            82        86             110            37
#
#    Vertical_Max_Reach  Vertical_No_Step  Vertical_No_Step_Reach  Weight  \
# 0                 147                33                     143     210
#
#    Reach_Height_Ratio  Wingspan_Height_Ratio  BMI  PTS  REB  AST  TPV
# 0                1.34                   1.05   22   18    7    4   34

# %%
prediction_player4 = rf_model2.predict(player4_df)

print('1 = All-Star')
print('0 = Not an All-Star')
print(f'For this player, the model predicts: {prediction_player4[0]}')
# Out:
# 1 = All-Star
# 0 = Not an All-Star
# For this player, the model predicts: 1

# %% [markdown]
# ## Conclusions

# %% [markdown]
# For both Backcourt and Frontcourt players, the Random Forest model performed quite well. The Random Forest model achieved an overall accuracy score of 89.58% for Backcourt players and 90.54% for Frontcourt players.
#
# This allows these models to be used for prediction with a relatively high level of confidence compared to other models made for this project.
